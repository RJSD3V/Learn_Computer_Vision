# %% [markdown]
# <a href="https://colab.research.google.com/github/RJSD3V/Learn_Computer_Vision/blob/master/fastai_vision.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Documentation for fastai.vision with experiments
#
# using the vision | fastai documentation, Im attempting to perform some deep learning experiments in order to understand the package in general.
#
# This is a part of the fastai deep learning course, where experimentation is encouraged rather than passive reading of theoretical material.

# %% [markdown]
# ##Quicky Tutorial
# Using the MNIST_Sample Data, here is a quicky model in a few lines of code.

# %%
from fastai.vision import *

# %%
import pathlib
path='/content/cifar10.tgz'

# %%
import tarfile
tar=tarfile.open(path)
tar.extractall('/content/sample_data/')

# %%
from pathlib import *
cifar_path=PosixPath('/content/sample_data/cifar10');cifar_path
# Out:
# PosixPath('/content/sample_data/cifar10')

# %%
cifar_train=cifar_path/'train'
cifar_test=cifar_path/'test'

# %%
cifar_labels=['airplane',
 'automobile',
 'bird',
 'cat',
 'deer',
 'dog',
 'frog',
 'horse',
 'ship',
 'truck',
 '']

# %%
data=ImageDataBunch.from_folder(cifar_path,train='train',valid='test',classes=cifar_labels,test=None,ds_tfms=get_transforms(),size=224,bs=64)

# %%
data.show_batch(5,figsize=(7,6))

# %%
print(data.classes)
print(data.c)
# Out:
# ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck', '']
# 11

# %%
learn=cnn_learner(data,models.resnet34,metrics=accuracy)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/checkpoints/resnet34-333f7ec4.pth
# ...

# %%
learn.fit(5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.341857</td>
#       <td>0.228260</td>
#       <td>0.919700</td>
#       <td>05:44</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.307612</td>
#       <td>0.184372</td>
#       <td>0.936400</td>
#       <td>05:46</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.259724</td>
#       <td>0.163469</td>
#       <td>0.941900</td>
#       <td>05:46</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.213161</td>
#       <td>0.157952</td>
#       <td>0.945300</td>
#       <td>05:46</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.203038</td>
#       <td>0.152403</td>
#       <td>0.950500</td>
#       <td>05:48</td>
#     </tr>
#   </tbody>
# </table>
